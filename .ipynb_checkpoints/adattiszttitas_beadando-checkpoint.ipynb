# %% [markdown]
# #### Adattisztítás beadandó feladatok megoldása

# %%
input('Név:')

# %%
input('Neptunkód:')

# %% [markdown]
# #### Oldja meg a Python Pandas Dataframe (műveletek).pdf és a Python Pandas Dataframe (ETL).pdf végén levő feladatokat, majd töltse fel a Github-ra.
# #### FONTOS! Legalább 3-szor Commit-teljen!
